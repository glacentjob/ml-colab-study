# %% [markdown]
# <a href="https://colab.research.google.com/github/glacentjob/ml-colab-study/blob/main/do-it-dl/Ch02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [10, 'hello list', 20]
display(my_list)
# Out:
# [10, 'hello list', 20]

# %%
dir(display)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
import numpy as np
display(np)
np.__version__
# Out:
# <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>
# '2.0.2'

# %%
my_array = np.array( [ [10,20,30], [40,50,60]])

display(my_array)
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
np.sum(my_array)
# Out:
# np.int64(210)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)

plt.scatter(x, y)
plt.show()
